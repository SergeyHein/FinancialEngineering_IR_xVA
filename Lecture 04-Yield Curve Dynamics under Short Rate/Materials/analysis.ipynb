# %%
from pysergws.filemodule import AutoFileModuleMonkey
from scipy.integrate import trapezoid

# %%
hw_cmp = AutoFileModuleMonkey("Hull_White_1F_2F_Comparison.py")
hw_cmp

# %%
hw_cmp_sim = AutoFileModuleMonkey("Hull-White-CompRateSim.py")
hw_cmp_sim

# %%
hw_z = AutoFileModuleMonkey("Hull-White-ZCBs2.py")
hw_z
